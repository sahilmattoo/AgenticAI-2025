# %%
pip list | grep -i langchain
# Out:
# langchain                         1.1.0
# langchain-classic                 1.0.0
# langchain-community               0.4.1
# langchain-core                    1.1.0
# langchain-groq                    1.1.0
# langchain-openai                  1.1.0
# langchain-text-splitters          1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

# Load environment variables from .env
load_dotenv()

# Create a ChatOpenAI model
model = ChatOpenAI(model="gpt-4o-mini")

# Define prompt templates (no need for separate Runnable chains)
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a comedian who tells jokes about {topic}."),
        ("human", "Tell me {joke_count} jokes."),
    ]
)

# Create the combined chain using LangChain Expression Language (LCEL)
chain = prompt_template | model | StrOutputParser()

# Run the chain
result = chain.invoke({"topic": "superhero", "joke_count": 3})

# Output
print(result)
# Out:
# Sure! Here are three superhero-themed jokes for you:
#
# 1. Why did Spider-Man break up with his girlfriend?
#    Because she found out he was still "web"-surfing!
#
# 2. How does Batman like his sandwiches?
#    With lots of "cape"-ers!
#
# 3. Why did the superhero take a break?
#    Because he needed to work on his "cape"-acity for relaxation!
#
# Hope you enjoyed them!

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.5
    )

# Simple query
response = llm.invoke("Explain quantum computing in simple terms max 50 words")
print(response.content)

from langchain_core.prompts import ChatPromptTemplate

# Create a prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI tutor. Respond to student questions clearly and shortest way possible."),
    ("human", "{input}")
])

# Set up the chain
chain = prompt | llm

# Interactive chat
print("AI Tutor: Hello! Ask me anything. Type 'quit' to exit.")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'quit':
        break
    response = chain.invoke({"input": user_input})
    print(f"AI Tutor: {response.content}")
# Out:
# Quantum computing uses the principles of quantum mechanics to process information. Unlike classical computers that use bits (0s and 1s), quantum computers use qubits, which can represent both 0 and 1 simultaneously, allowing them to solve complex problems much faster than traditional computers.
# AI Tutor: Hello! Ask me anything. Type 'quit' to exit.
# AI Tutor: Calculus is a branch of mathematics that studies how things change. It focuses on two main concepts:
#
# 1. **Differentiation**: This deals with rates of change and slopes of curves. It helps find the instantaneous rate of change of a function at any point.
#
# 2. **Integration**: This involves finding the total accumulation of quantities, such as areas under curves. It sums up small pieces to find a whole.
#
# Together, these concepts allow us to analyze dynamic systems in physics, engineering, economics, and more.

# %%
# Task-planner agent using langchain
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert task planner. Break down complex tasks into manageable steps."),
    ("human", "{task_description}")
])
chain = prompt | llm
task_description = "Plan a week-long trip to Japan focusing on cultural experiences."
response = chain.invoke({"task_description": task_description})
print(response.content)
# Out:
# Planning a week-long trip to Japan with a focus on cultural experiences requires careful consideration of destinations, activities, and logistics. Below is a detailed itinerary that breaks down your trip into manageable steps.
#
# ### Day 1: Arrival in Tokyo
# **Morning:**
# - Arrive at Narita or Haneda Airport.
# - Transfer to your accommodation (hotel or traditional ryokan).
#
# **Afternoon:**
# - Explore Asakusa: Visit Senso-ji Temple, the oldest temple in Tokyo.
# - Stroll through Nakamise Street for traditional snacks and souvenirs.
#
# **Evening:**
# - Dinner at a local izakaya (Japanese pub) in Asakusa.
# - Rest and adjust to the time zone.
#
# ### Day 2: Tokyo Cultural Exploration
# **Morning:**
# - Visit the Meiji Shrine, a Shinto shrine surrounded by a beautiful forest.
#
# **Afternoon:**
# - Explore Harajuku: Check out Takeshita Street for youth culture and fashion.
# - Visit the Nezu Museum for traditional Japanese art and gardens.
#
# **Evening:**
# - Attend a traditional tea ceremony experience.
# - Dinner in Shibuya, followed by a visit to the famous Shibuya Crossing.
#
# ### Day 3: Day Trip to Nikko
# **Morning:**
# - Take an early train to Nikko (approximately 2 hours).
# - Visit the UNESCO World Heritage Site of Toshogu Shrine.
#
# **Afternoon:**
# - Explore the natural beauty of Nikko National Park: Kegon Falls and Lake Chuzenji.
#
# **Evening:**
# - Return to Tokyo and enjoy a quiet dinner near your accommodation.
#
# ### Day 4: Kyoto
# **Morning:**
# - Take the Shinkansen (bullet train) to Kyoto (approximately 2.5 hours).
# - Check in to your accommodation (preferably a ryokan for an authentic experience).
#
# **Afternoon:**
# - Visit Kinkaku-ji (Golden Pavilion) and its beautiful gardens.
#
# **Evening:**
# - Explore Gion district: Walk through the historic streets and possibly spot a geisha.
# - Dinner at a kaiseki restaurant (traditional multi-course meal).
#
# ### Day 5: Kyoto Cultural Immersion
# **Morning:**
# - Participate in a kimono-wearing experience and stroll through the Arashiyama Bamboo Grove.
#
# **Afternoon:**
# - Visit Tenryu-ji Temple, a UNESCO World Heritage Site.
# - Take a boat ride on the Hozu River.
#
# **Evening:**
# - Attend a traditional Japanese performance (such as a tea ceremony or kabuki show).
#
# ### Day 6: Osaka Day Trip
# **Morning:**
# - Take a short train ride to Osaka (approximately 30 minutes).
# - Visit Osaka Castle and its surrounding park.
#
# **Afternoon:**
# - Explore the Dotonbori district: Try street food like takoyaki and okonomiyaki.
#
# **Evening:**
# - Visit the Umeda Sky Building for panoramic views of the city at sunset.
# - Return to Kyoto for the night.
#
# ### Day 7: Nara and Departure
# **Morning:**
# - Take a train to Nara (approximately 1 hour).
# - Visit Todai-ji Temple, home to a giant Buddha statue, and Nara Park with its free-roaming deer.
#
# **Afternoon:**
# - Explore Kasuga-taisha Shrine and its beautiful paths lined with lanterns.
# - Return to Kyoto or head directly to Kansai International Airport (if flying out from Osaka).
#
# **Evening:**
# - Depart from Japan, taking with you unforgettable cultural experiences.
#
# ### Additional Tips:
# - **Transportation:** Consider purchasing a Japan Rail Pass for unlimited travel on JR trains, including the Shinkansen.
# - **Accommodation:** Book stays in both modern hotels for comfort and traditional ryokans for cultural immersion.
# - **Language:** Download translation apps and familiarize yourself with basic Japanese phrases.
# - **Etiquette:** Research Japanese customs and etiquette to enhance your cultural experience.
#
# This itinerary allows you to immerse yourself in Japan's rich culture while providing a balance of activities and relaxation. Enjoy your trip!
