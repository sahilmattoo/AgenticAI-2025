# %%
portfolio = {
    "RELIANCE.NS": 2450,
    "TCS.NS": 3850,
    "INFY.NS": 1750,
    "HDFCBANK.NS": 1650,
    "ICICIBANK.NS": 1250,
    "SBIN.NS": 820,
    "ITC.NS": 480,
    "BHARTIARTL.NS": 1650,
    "LT.NS": 3650,
    "ADANIENT.NS": 2500
}
