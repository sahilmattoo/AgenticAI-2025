# %%
# !pip install yfinance

# %%
import yfinance as yf

ril = yf.Ticker("RELIANCE.NS")

data = ril.history(period="1d")

print(data)
# Out:
#                                   Open         High     Low   Close   Volume  \
# Date
# 2026-08-28 00:00:00+05:30  1284.900024  1291.800049  1280.0  1287.0  6830228
#
#                            Dividends  Stock Splits
# Date
# 2026-08-28 00:00:00+05:30        0.0           0.0

# %%
pwd
# Out:
# '/content'

# %%
path ="/content/drive/MyDrive/[06] Learning and Teaching/Transit_Folder/IITM-Aug26"
path = "/content/drive/MyDrive/[06] Learning and Teaching/[01] Transit_Folder/[01] AI/Batch/AI2026"

# %%
import os
os.chdir(path)

# %%
pwd
# Out:
# '/content/drive/MyDrive/[06] Learning and Teaching/[01] Transit_Folder/[01] AI/Batch/AI2026'

# %%
# !ls
# Out:
#  Week1	'Week 2'   Week3

# %%
# %cd Week3
# Out:
# /content/drive/MyDrive/[06] Learning and Teaching/[01] Transit_Folder/[01] AI/Batch/AI2026/Week3

# %%
pwd
# Out:
# '/content/drive/MyDrive/[06] Learning and Teaching/[01] Transit_Folder/[01] AI/Batch/AI2026/Week3'

# %%
# %cd app/
# Out:
# /content/drive/MyDrive/[06] Learning and Teaching/[01] Transit_Folder/[01] AI/Batch/AI2026/Week3/app

# %%
# !ls
# Out:
# Nse-api.ipynb		portfoliomanager.py  util.py
# portfoliomanager.ipynb	__pycache__

# %%
import portfoliomanager as pf

# %%
pf.portfolio
# Out:
# {'RELIANCE.NS': 2450,
#  'TCS.NS': 3850,
#  'INFY.NS': 1750,
#  'HDFCBANK.NS': 1650,
#  'ICICIBANK.NS': 1250,
#  'SBIN.NS': 820,
#  'ITC.NS': 480,
#  'BHARTIARTL.NS': 1650,
#  'LT.NS': 3650,
#  'ADANIENT.NS': 2500}

# %%
def getCurrentPrice(stockName):
  ticker = yf.Ticker(stockName)
  todaysData = ticker.history()
  currentprice = todaysData["Close"][-1]
  return currentprice

# %%
stockName = "RELIANCE.NS"

# %%
currPrice = getCurrentPrice(stockName)
# Out:
# /tmp/ipykernel_2232/2594783309.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   currentprice = todaysData["Close"][-1]

# %%
currPrice
# Out:
# np.float64(1287.0)

# %%
print(float(currPrice))
# Out:
# 1287.0

# %%
import util as utils

# %%
benchmarkprice = pf.portfolio[stockName]
benchmarkprice
# Out:
# 2450

# %%
utils.stock_utility(stock= stockName, stock_value= benchmarkprice, current_price=currPrice)
# Out:
# ('RELIANCE.NS', np.float64(-47.46938775510204), 'BUY')
