# %% [markdown]
# __*Reinforcement Loop*__
# (Optional in case needs to explain reinforcement learning with Python and LLM without using any agentic framework)

# %% [markdown]
# LLM-Driven Reinforcement Learning in Pure Python (Framework-Free Approach)

# %% [markdown]
# This Python-only Reinforcement Learning loop demonstrates a lightweight, interpretable, and practical method for making LLM agents improve over time. It blends:
#
# ✔ RL concepts
#
# ✔ LLM reasoning
#
# ✔ Pure Python
#
# ✔ Dynamic policy refinement
#
# …all without needing CrewAI, or any Agentic framework.

# %%
pip list | grep -i langchain
# Out:
# langchain                                0.1.13
# langchain-cohere                         0.1.5
# langchain-community                      0.0.29
# langchain-core                           0.1.53
# langchain-openai                         0.1.7
# langchain-text-splitters                 0.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Setup

import os
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
# Load environment variables
load_dotenv()

import warnings
warnings.filterwarnings('ignore')
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
# 1: Basic Reinforcement Loop Framework
from langchain.schema import HumanMessage, SystemMessage
import json
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

class ReinforcementAgent:
    def __init__(self, initial_strategy):
        self.strategy = initial_strategy
        self.learning_history = []
        self.success_rate = 0.5  # Start with neutral assumption
        
    def act(self, situation):
        """Take action based on current strategy"""
        response = llm.invoke([
            SystemMessage(content=f"Current strategy: {self.strategy}"),
            HumanMessage(content=f"Handle this situation: {situation}")
        ])
        return response.content
    
    def observe(self, feedback_score, details):
        """Receive feedback from environment"""
        observation = {
            'feedback_score': feedback_score,  # 1-5 scale
            'details': details,
            'strategy_used': self.strategy
        }
        self.learning_history.append(observation)
        return observation
    
    def adapt(self):
        """Update strategy based on learning history"""
        if not self.learning_history:
            return "No learning data yet"
            
        # Calculate recent success rate (last 5 interactions)
        recent = self.learning_history[-5:]
        if recent:
            success_count = sum(1 for obs in recent if obs['feedback_score'] >= 4)
            self.success_rate = success_count / len(recent)
        
        # Adapt strategy if performing poorly
        if self.success_rate < 0.6:
            new_strategy = self._improve_strategy()
            improvement = f"Strategy updated due to low success rate ({self.success_rate:.1%})"
            self.strategy = new_strategy
            return improvement
        else:
            return f"Strategy working well ({self.success_rate:.1%} success), maintaining approach"
    
    def _improve_strategy(self):
        """Get improved strategy from LLM based on failures"""
        recent_failures = [obs for obs in self.learning_history[-3:] if obs['feedback_score'] <= 2]
        
        if not recent_failures:
            return self.strategy
            
        failure_analysis = "\n".join([f"Failure: {obs['details']}" for obs in recent_failures])
        
        response = llm.invoke([
            SystemMessage(content="Analyze failures and suggest better strategy"),
            HumanMessage(content=f"Current strategy: {self.strategy}\nRecent failures:\n{failure_analysis}\nSuggest improved approach:")
        ])
        return response.content

# Create a customer service agent with initial strategy
cs_agent = ReinforcementAgent(
    initial_strategy="Be polite and provide standard shipping information"
)

print("Reinforcement Loop Agent Created!")
print(f"Initial Strategy: {cs_agent.strategy}")
# Out:
# Reinforcement Loop Agent Created!
# Initial Strategy: Be polite and provide standard shipping information

# %%
print(cs_agent.strategy)
# Out:
# Be polite and provide standard shipping information

# %%
# 2 Demo - Learning from Customer Interactions
def demonstrate_learning_loop():
    print("DEMONSTRATING REINFORCEMENT LEARNING LOOP")
    print("=" * 50)
    
    # Scenario 1: First interaction (poor outcome)
    situation1 = "Customer: My order #12345 is 3 days late! I need it for an important event."
    
    print("\nINTERACTION 1: Late Order Complaint")
    print(f"Situation: {situation1}")
    
    # ACT
    response1 = cs_agent.act(situation1)
    print(f"AI Response: {response1}")
    
    # OBSERVE (Customer gives 1/5 stars)
    observation1 = cs_agent.observe(
        feedback_score=1, 
        details="Customer angry - AI was dismissive about late order"
    )
    print(f"Feedback: {observation1['feedback_score']}/5 - {observation1['details']}")
    
    # ADAPT
    adaptation1 = cs_agent.adapt()
    print(f"Learning: {adaptation1}")
    print(f"Updated Strategy: {cs_agent.strategy}")

demonstrate_learning_loop()
# Out:
# DEMONSTRATING REINFORCEMENT LEARNING LOOP
# ==================================================
#
# INTERACTION 1: Late Order Complaint
# Situation: Customer: My order #12345 is 3 days late! I need it for an important event.
# AI Response: I'm sorry to hear that your order is delayed. I understand how important it is to receive it on time, especially for an event. I recommend checking the tracking information for the latest updates. If you need further assistance, please let me know, and I can help you with any options available. Thank you for your patience!
# Feedback: 1/5 - Customer angry - AI was dismissive about late order
# Learning: Strategy updated due to low success rate (0.0%)
# Updated Strategy: To address the recent failure of a customer feeling dismissed regarding a late order, it's essential to adopt a more empathetic and proactive approach. Here’s an improved strategy:
#
# ### Improved Approach:
#
# 1. **Acknowledge the Customer's Feelings:**
#    - Start by recognizing the customer's frustration. Use empathetic language to show that you understand their concerns.
#    - Example: "I completely understand how frustrating it can be to experience a delay with your order. I’m here to help you."
#
# 2. **Provide Specific Information:**
#    - Instead of just giving standard shipping information, provide specific details about the order status. If possible, include reasons for the delay and an estimated resolution time.
#    - Example: "Your order was scheduled to arrive on [original date], but due to [specific reason], it has been delayed. We expect it to be shipped by [new date]."
#
# 3. **Offer Solutions:**
#    - Suggest alternatives or solutions to mitigate the inconvenience. This could include expedited shipping options, discounts, or compensation for the delay.
#    - Example: "To make up for the inconvenience, I can offer you a [discount, free shipping on your next order, etc.]. Would that be acceptable?"
#
# 4. **Encourage Further Communication:**
#    - Invite the customer to ask questions or express any additional concerns. This shows that you value their input and are willing to assist further.
#    - Example: "If you have any more questions or need further assistance, please don’t hesitate to reach out. I’m here to help!"
#
# 5. **Follow-Up:**
#    - After resolving the issue, consider following up with the customer to ensure they received their order and are satisfied with the resolution. This can help rebuild trust and improve customer loyalty.
#    - Example: "I just wanted to check in and see if your order has arrived and if everything is to your satisfaction."
#
# ### Summary:
# By incorporating empathy, specific information, proactive solutions, open communication, and follow-up, you can significantly improve customer satisfaction and reduce feelings of dismissal. This approach not only addresses the immediate issue but also fosters a positive relationship with the customer moving forward.

# %%
print(cs_agent.strategy)
# Out:
# To address the recent failure of a customer feeling dismissed regarding a late order, it's essential to adopt a more empathetic and proactive approach. Here’s an improved strategy:
#
# ### Improved Approach:
#
# 1. **Acknowledge the Customer's Feelings:**
#    - Start by recognizing the customer's frustration. Use empathetic language to show that you understand their concerns.
#    - Example: "I completely understand how frustrating it can be to experience a delay with your order. I’m here to help you."
#
# 2. **Provide Specific Information:**
#    - Instead of just giving standard shipping information, provide specific details about the order status. If possible, include reasons for the delay and an estimated resolution time.
#    - Example: "Your order was scheduled to arrive on [original date], but due to [specific reason], it has been delayed. We expect it to be shipped by [new date]."
#
# 3. **Offer Solutions:**
#    - Suggest alternatives or solutions to mitigate the inconvenience. This could include expedited shipping options, discounts, or compensation for the delay.
#    - Example: "To make up for the inconvenience, I can offer you a [discount, free shipping on your next order, etc.]. Would that be acceptable?"
#
# 4. **Encourage Further Communication:**
#    - Invite the customer to ask questions or express any additional concerns. This shows that you value their input and are willing to assist further.
#    - Example: "If you have any more questions or need further assistance, please don’t hesitate to reach out. I’m here to help!"
#
# 5. **Follow-Up:**
#    - After resolving the issue, consider following up with the customer to ensure they received their order and are satisfied with the resolution. This can help rebuild trust and improve customer loyalty.
#    - Example: "I just wanted to check in and see if your order has arrived and if everything is to your satisfaction."
#
# ### Summary:
# By incorporating empathy, specific information, proactive solutions, open communication, and follow-up, you can significantly improve customer satisfaction and reduce feelings of dismissal. This approach not only addresses the immediate issue but also fosters a positive relationship with the customer moving forward.

# %%
# 3: Multiple Learning Iterations
def run_learning_simulation():
    """Simulate multiple customer interactions with learning"""
    
    scenarios = [
        {
            "situation": "Customer: I received the wrong size. This is very frustrating!",
            "good_response": "Apologize sincerely, offer immediate replacement and discount",
            "poor_response": "Explain return policy without empathy"
        },
        {
            "situation": "Customer: The product quality is much lower than advertised",
            "good_response": "Acknowledge concern, offer refund or exchange, ask for details",
            "poor_response": "Defend product quality and refer to manufacturer"
        },
        {
            "situation": "Customer: Your website charged me twice for the same order!",
            "good_response": "Apologize for error, verify duplicate charge, process immediate refund",
            "poor_response": "Ask customer to check their bank statement first"
        }
    ]
    
    print("\n" + "FULL LEARNING SIMULATION" + "=" * 50)
    
    for i, scenario in enumerate(scenarios, 1):
        print(f"\n ITERATION {i}:")
        print(f"Situation: {scenario['situation']}")
        
        # ACT
        response = cs_agent.act(scenario['situation'])
        print(f"AI Response: {response[:100]}...")
        
        # Simulate feedback based on response quality
        if any(keyword in response.lower() for keyword in ['apologize', 'sorry', 'immediately', 'refund']):
            feedback_score = 5  # Good response
            feedback_details = "Customer satisfied - empathetic and solution-oriented"
        else:
            feedback_score = 2  # Poor response  
            feedback_details = "Customer frustrated - lacking empathy and immediate solutions"
        
        # OBSERVE
        cs_agent.observe(feedback_score, feedback_details)
        print(f"Feedback: {feedback_score}/5 - {feedback_details}")
        
        # ADAPT
        learning = cs_agent.adapt()
        print(f"Learning: {learning}")
        
        print(f"Success Rate: {cs_agent.success_rate:.1%}")

run_learning_simulation()
# Out:
# FULL LEARNING SIMULATION==================================================
#
#  ITERATION 1:
# Situation: Customer: I received the wrong size. This is very frustrating!
# AI Response: ### Response to Customer:
#
# 1. **Acknowledge the Customer's Feelings:**
#    - "I’m really sorry to hea...
# Feedback: 5/5 - Customer satisfied - empathetic and solution-oriented
# Learning: Strategy updated due to low success rate (50.0%)
# Success Rate: 50.0%
#
#  ITERATION 2:
# Situation: Customer: The product quality is much lower than advertised
# AI Response: ### Response to Customer Concern About Product Quality
#
# 1. **Immediate Acknowledgment and Apology:**...
# Feedback: 5/5 - Customer satisfied - empathetic and solution-oriented
# Learning: Strategy working well (66.7% success), maintaining approach
# Success Rate: 66.7%
#
#  ITERATION 3:
# Situation: Customer: Your website charged me twice for the same order!
# AI Response: 1. **Immediate Acknowledgment and Apology:**
#    - "I’m really sorry to hear that you were charged tw...
# Feedback: 5/5 - Customer satisfied - empathetic and solution-oriented
# Learning: Strategy working well (75.0% success), maintaining approach
# Success Rate: 75.0%

# %%
print(cs_agent.strategy)
# Out:
# To address the recent failure of a customer feeling dismissed regarding a late order, it's essential to adopt a more empathetic and proactive approach. Here’s an improved strategy:
#
# ### Improved Approach:
#
# 1. **Acknowledge the Customer's Feelings:**
#    - Start by recognizing the customer's frustration. Use empathetic language to show that you understand their concerns.
#    - Example: "I completely understand how frustrating it can be to experience a delay with your order. I’m here to help you."
#
# 2. **Provide Specific Information:**
#    - Instead of just giving standard shipping information, provide specific details about the order status. If possible, include reasons for the delay and an estimated resolution time.
#    - Example: "Your order was scheduled to arrive on [original date], but due to [specific reason], it has been delayed. We expect it to be shipped by [new date]."
#
# 3. **Offer Solutions:**
#    - Suggest alternatives or solutions to mitigate the inconvenience. This could include expedited shipping options, discounts, or compensation for the delay.
#    - Example: "To make up for the inconvenience, I can offer you a [discount, free shipping on your next order, etc.]. Would that be acceptable?"
#
# 4. **Encourage Further Communication:**
#    - Invite the customer to ask questions or express any additional concerns. This shows that you value their input and are willing to assist further.
#    - Example: "If you have any more questions or need further assistance, please don’t hesitate to reach out. I’m here to help!"
#
# 5. **Follow-Up:**
#    - After resolving the issue, consider following up with the customer to ensure they received their order and are satisfied with the resolution. This can help rebuild trust and improve customer loyalty.
#    - Example: "I just wanted to check in and see if your order has arrived and if everything is to your satisfaction."
#
# ### Summary:
# By incorporating empathy, specific information, proactive solutions, open communication, and follow-up, you can significantly improve customer satisfaction and reduce feelings of dismissal. This approach not only addresses the immediate issue but also fosters a positive relationship with the customer moving forward.

# %%
# 4: Advanced Planning with Reinforcement
class AdvancedPlanningAgent:
    def __init__(self, domain):
        self.domain = domain
        self.plan_templates = self._load_plan_templates()
        self.execution_history = []
    
    def _load_plan_templates(self):
        """Initial plan templates for different scenarios"""
        return {
            "complaint": ["1. Acknowledge issue", "2. Investigate details", "3. Offer solution", "4. Follow up"],
            "inquiry": ["1. Understand question", "2. Provide information", "3. Check understanding", "4. Offer further help"],
            "emergency": ["1. Assess urgency", "2. Take immediate action", "3. Escalate if needed", "4. Document resolution"]
        }
    
    def create_plan(self, situation):
        """Create adaptive plan based on situation type"""
        situation_type = self._classify_situation(situation)
        base_plan = self.plan_templates.get(situation_type, self.plan_templates["inquiry"])
        
        # Adapt plan based on context
        adapted_plan = self._adapt_plan(base_plan, situation)
        return adapted_plan
    
    def _classify_situation(self, situation):
        """Classify what type of situation this is"""
        response = llm.invoke([
            SystemMessage(content="Classify customer situation type: complaint, inquiry, or emergency"),
            HumanMessage(content=f"Situation: {situation}\nRespond with just one word: complaint, inquiry, or emergency")
        ])
        return response.content.strip().lower()
    
    def _adapt_plan(self, base_plan, situation):
        """Adapt plan based on specific situation details"""
        plan_str = "\n".join(base_plan)
        response = llm.invoke([
            SystemMessage(content="Adapt this plan to fit the specific situation better"),
            HumanMessage(content=f"Base plan:\n{plan_str}\n\nSituation: {situation}\nSuggest 1-2 specific adaptations:")
        ])
        adapted_steps = base_plan + [f"Adapted: {response.content}"]
        return adapted_steps
    
    def execute_with_feedback(self, situation):
        """Full execution with reinforcement learning"""
        print(f"\nExecuting plan for: {situation}")
        
        # Create plan
        plan = self.create_plan(situation)
        print("Plan created:")
        for step in plan:
            print(f"  - {step}")
        
        # Execute plan
        result = self.act(situation)
        print(f"Execution result: {result[:150]}...")
        
        # Simulate feedback
        feedback = self.simulate_feedback(result)
        print(f"Feedback: {feedback}/5")
        
        # Learn from execution
        self.learn_from_execution(situation, plan, feedback)
        
        return result
    
    def act(self, situation):
        """Execute the plan"""
        response = llm.invoke([
            SystemMessage(content="Execute this customer service interaction professionally"),
            HumanMessage(content=situation)
        ])
        return response.content
    
    def simulate_feedback(self, response):
        """Simulate customer feedback based on response quality"""
        positive_indicators = ['apologize', 'understand', 'solution', 'immediately', 'help', 'resolve']
        score = 3  # Neutral start
        
        for indicator in positive_indicators:
            if indicator in response.lower():
                score += 0.5
                
        return min(5, max(1, score))
    
    def learn_from_execution(self, situation, plan, feedback):
        """Reinforcement learning from execution results"""
        learning_entry = {
            'situation': situation,
            'plan_used': plan,
            'feedback': feedback,
            'learned_at': len(self.execution_history) + 1
        }
        self.execution_history.append(learning_entry)
        
        # Simple learning: if feedback poor, note for future adaptation
        if feedback <= 2:
            print("Learning: This approach didn't work well for similar situations")

# Demo advanced planning agent
print("\n" + "ADVANCED PLANNING AGENT DEMO" + "=" * 50)
planning_agent = AdvancedPlanningAgent("customer_service")

test_situations = [
    "Customer: Your delivery service lost my package! It had important documents inside.",
    "Customer: Can you tell me about your return policy for electronics?",
    "Customer: There's a security issue with my account - someone unauthorized made purchases!"
]

for situation in test_situations:
    planning_agent.execute_with_feedback(situation)
# Out:
# ADVANCED PLANNING AGENT DEMO==================================================
#
# Executing plan for: Customer: Your delivery service lost my package! It had important documents inside.
# Plan created:
#   - 1. Acknowledge issue
#   - 2. Investigate details
#   - 3. Offer solution
#   - 4. Follow up
#   - Adapted: 1. Acknowledge the urgency: Begin by expressing understanding of the situation's seriousness, emphasizing the importance of the documents and the inconvenience caused by the lost package.
#
# 2. Provide immediate assistance: Instead of just investigating the details, offer to initiate a trace on the package right away and provide the customer with a timeline for when they can expect updates. Additionally, discuss potential options for replacing the important documents if they cannot be recovered quickly.
# Execution result: Customer Service Representative: I’m very sorry to hear that your package has been lost, and I understand how important those documents are to you. Le...
# Feedback: 4.5/5
#
# Executing plan for: Customer: Can you tell me about your return policy for electronics?
# Plan created:
#   - 1. Understand question
#   - 2. Provide information
#   - 3. Check understanding
#   - 4. Offer further help
#   - Adapted: Adaptation 1: Include specific details about the return policy for electronics in the information provided. For example, mention the time frame for returns, any conditions that must be met (such as original packaging or receipt), and whether there are any restocking fees.
#
# Adaptation 2: After providing the information, ask a follow-up question to ensure clarity, such as, "Does that answer your question about our return policy for electronics, or is there a specific product you have in mind?" This encourages further engagement and addresses any specific concerns the customer may have.
# Execution result: Customer Service Representative: Absolutely! Our return policy for electronics allows you to return items within 30 days of purchase, provided they ar...
# Feedback: 3/5
#
# Executing plan for: Customer: There's a security issue with my account - someone unauthorized made purchases!
# Plan created:
#   - 1. Assess urgency
#   - 2. Take immediate action
#   - 3. Escalate if needed
#   - 4. Document resolution
#   - Adapted: 1. **Prioritize Security Assessment**: Given the nature of the issue, immediately assess the security of the customer's account by verifying recent activity and identifying any unauthorized transactions. This step should be prioritized over general urgency assessment.
#
# 2. **Implement Account Lockdown**: Take immediate action by temporarily locking the customer's account to prevent further unauthorized access while you investigate the issue. This ensures the customer's information is protected during the resolution process.
# Execution result: Customer Service Representative: I'm very sorry to hear that you're experiencing this issue. Your account security is our top priority. Can you please...
# Feedback: 3.5/5

# %%
# 5: Real-time Strategy Adaptation Demo
def show_strategy_evolution():
    """Show how strategy evolves through reinforcement"""
    
    print("\n STRATEGY EVOLUTION THROUGH REINFORCEMENT")
    print("=" * 50)
    
    # Track strategy changes
    strategies = []
    
    # Create new agent
    learning_agent = ReinforcementAgent(
        initial_strategy="Provide factual information to customer queries"
    )
    
    strategies.append(learning_agent.strategy)
    
    # Learning iterations
    learning_scenarios = [
        ("Customer is angry about service outage", 1, "Too factual, lacked empathy"),
        ("Customer confused about billing", 3, "Clear but could be more helpful"), 
        ("Customer needs urgent help", 2, "Too slow, didn't recognize urgency"),
        ("Customer happy but has question", 5, "Good balance of info and friendliness")
    ]
    
    for i, (situation, feedback, reason) in enumerate(learning_scenarios, 1):
        print(f"\nLearning Cycle {i}:")
        print(f"Situation: {situation}")
        print(f"Current Strategy: {learning_agent.strategy}")
        
        # ACT and OBSERVE
        learning_agent.act(situation)
        learning_agent.observe(feedback, reason)
        
        # ADAPT 
        change = learning_agent.adapt()
        strategies.append(learning_agent.strategy)
        
        print(f"Strategy Change: {change}")
        print(f"New Strategy: {learning_agent.strategy}")
    
    print(f"\nFINAL STRATEGY: {learning_agent.strategy}")
    print(f"Final Success Rate: {learning_agent.success_rate:.1%}")

show_strategy_evolution()
# Out:
#  STRATEGY EVOLUTION THROUGH REINFORCEMENT
# ==================================================
#
# Learning Cycle 1:
# Situation: Customer is angry about service outage
# Current Strategy: Provide factual information to customer queries
# Strategy Change: Strategy updated due to low success rate (0.0%)
# New Strategy: To enhance your current strategy of providing factual information while addressing the recent failures of lacking empathy, consider the following improved approach:
#
# ### 1. **Empathetic Communication:**
#    - **Acknowledge Emotions:** Start by recognizing the customer's feelings or concerns. Use phrases like "I understand how frustrating this must be for you" or "I can see why you would feel that way."
#    - **Personalize Responses:** Use the customer's name and reference their specific situation to make the interaction feel more personal and less robotic.
#
# ### 2. **Active Listening:**
#    - **Encourage Dialogue:** Ask open-ended questions to better understand the customer's needs and feelings. For example, "Can you tell me more about what you're experiencing?"
#    - **Reflect Back:** Summarize what the customer has said to show that you are listening and to clarify any misunderstandings.
#
# ### 3. **Balanced Information Delivery:**
#    - **Combine Facts with Support:** When providing factual information, pair it with supportive language. For instance, "While the policy states X, I understand that this may not be what you were hoping for, and I'm here to help you navigate this."
#    - **Offer Solutions:** Instead of just stating facts, suggest actionable steps the customer can take. This shows that you are invested in resolving their issue.
#
# ### 4. **Follow-Up:**
#    - **Check-In:** After resolving the query, follow up with the customer to see if they need further assistance. This demonstrates ongoing support and care.
#    - **Feedback Loop:** Encourage customers to provide feedback on their experience, which can help you continuously improve your empathetic approach.
#
# ### 5. **Training and Development:**
#    - **Empathy Training:** Invest in training for your team focused on emotional intelligence and empathetic communication skills.
#    - **Role-Playing Scenarios:** Conduct role-playing exercises to practice responding to customer queries with both factual information and empathy.
#
# ### 6. **Utilize Technology:**
#    - **AI and Chatbots:** If using automated systems, ensure they are programmed to recognize emotional cues and respond with empathy. For example, a chatbot could use empathetic language when addressing customer concerns.
#
# ### 7. **Create a Supportive Culture:**
#    - **Encourage Empathy Among Staff:** Foster a workplace culture that values empathy and customer care, which can translate into better customer interactions.
#    - **Recognize and Reward Empathy:** Acknowledge team members who exemplify empathetic customer service, reinforcing the importance of this approach.
#
# By integrating these strategies, you can create a more balanced approach that not only provides factual information but also connects with customers on an emotional level, ultimately leading to improved customer satisfaction and loyalty.
#
# Learning Cycle 2:
# Situation: Customer confused about billing
# Current Strategy: To enhance your current strategy of providing factual information while addressing the recent failures of lacking empathy, consider the following improved approach:
#
# ### 1. **Empathetic Communication:**
#    - **Acknowledge Emotions:** Start by recognizing the customer's feelings or concerns. Use phrases like "I understand how frustrating this must be for you" or "I can see why you would feel that way."
#    - **Personalize Responses:** Use the customer's name and reference their specific situation to make the interaction feel more personal and less robotic.
#
# ### 2. **Active Listening:**
#    - **Encourage Dialogue:** Ask open-ended questions to better understand the customer's needs and feelings. For example, "Can you tell me more about what you're experiencing?"
#    - **Reflect Back:** Summarize what the customer has said to show that you are listening and to clarify any misunderstandings.
#
# ### 3. **Balanced Information Delivery:**
#    - **Combine Facts with Support:** When providing factual information, pair it with supportive language. For instance, "While the policy states X, I understand that this may not be what you were hoping for, and I'm here to help you navigate this."
#    - **Offer Solutions:** Instead of just stating facts, suggest actionable steps the customer can take. This shows that you are invested in resolving their issue.
#
# ### 4. **Follow-Up:**
#    - **Check-In:** After resolving the query, follow up with the customer to see if they need further assistance. This demonstrates ongoing support and care.
#    - **Feedback Loop:** Encourage customers to provide feedback on their experience, which can help you continuously improve your empathetic approach.
#
# ### 5. **Training and Development:**
#    - **Empathy Training:** Invest in training for your team focused on emotional intelligence and empathetic communication skills.
#    - **Role-Playing Scenarios:** Conduct role-playing exercises to practice responding to customer queries with both factual information and empathy.
#
# ### 6. **Utilize Technology:**
#    - **AI and Chatbots:** If using automated systems, ensure they are programmed to recognize emotional cues and respond with empathy. For example, a chatbot could use empathetic language when addressing customer concerns.
#
# ### 7. **Create a Supportive Culture:**
#    - **Encourage Empathy Among Staff:** Foster a workplace culture that values empathy and customer care, which can translate into better customer interactions.
#    - **Recognize and Reward Empathy:** Acknowledge team members who exemplify empathetic customer service, reinforcing the importance of this approach.
#
# By integrating these strategies, you can create a more balanced approach that not only provides factual information but also connects with customers on an emotional level, ultimately leading to improved customer satisfaction and loyalty.
# Strategy Change: Strategy updated due to low success rate (0.0%)
# New Strategy: To address the recent failures of providing overly factual responses without sufficient empathy, the following improved approach can be implemented:
#
# ### 1. **Empathetic Communication:**
#    - **Acknowledge Emotions:** Begin interactions by validating the customer's feelings. Use empathetic phrases such as "I understand how this situation can be upsetting" or "It’s completely normal to feel this way."
#    - **Personalize Responses:** Incorporate the customer's name and specific details about their situation to create a more personal connection. For example, "Thank you for reaching out, [Customer's Name]. I see that you’re facing an issue with [specific issue]."
#
# ### 2. **Active Listening:**
#    - **Encourage Dialogue:** Use open-ended questions to invite customers to share more about their experiences. For instance, "What specific challenges are you facing with this issue?"
#    - **Reflect Back:** Paraphrase the customer's concerns to demonstrate understanding and ensure clarity. For example, "So what I’m hearing is that you’re feeling frustrated because [summarize their concern]. Is that correct?"
#
# ### 3. **Balanced Information Delivery:**
#    - **Combine Facts with Support:** When delivering factual information, accompany it with empathetic language. For example, "While our policy states X, I understand that this may not be the outcome you were hoping for, and I’m here to help you find a solution."
#    - **Offer Solutions:** Instead of merely stating facts, provide actionable steps the customer can take. For example, "You can try [solution], and I can guide you through the process."
#
# ### 4. **Follow-Up:**
#    - **Check-In:** After resolving the issue, follow up with the customer to ensure their needs are met. A simple message like, "I just wanted to check in and see if everything is working well for you now," can go a long way.
#    - **Feedback Loop:** Encourage customers to share their feedback on the interaction, which can help refine your empathetic approach. Ask questions like, "How did you feel about our conversation today?"
#
# ### 5. **Training and Development:**
#    - **Empathy Training:** Provide training sessions focused on developing emotional intelligence and empathetic communication skills among team members.
#    - **Role-Playing Scenarios:** Implement role-playing exercises that simulate customer interactions, allowing team members to practice responding with empathy while delivering factual information.
#
# ### 6. **Utilize Technology:**
#    - **AI and Chatbots:** If using automated systems, ensure they are designed to recognize emotional cues and respond with empathy. For example, a chatbot could say, "I’m sorry to hear that you’re having trouble. Let’s see how I can assist you."
#
# ### 7. **Create a Supportive Culture:**
#    - **Encourage Empathy Among Staff:** Foster a workplace culture that prioritizes empathy and customer care, which can enhance customer interactions.
#    - **Recognize and Reward Empathy:** Acknowledge and reward team members who demonstrate exceptional empathetic customer service, reinforcing the importance of this approach.
#
# ### 8. **Continuous Improvement:**
#    - **Monitor Interactions:** Regularly review customer interactions to identify areas for improvement in empathetic communication.
#    - **Adapt Strategies:** Be open to adapting strategies based on customer feedback and changing needs, ensuring that empathy remains a core component of your service.
#
# By implementing these strategies, you can create a more holistic approach that not only delivers factual information but also fosters emotional connections with customers, leading to enhanced satisfaction and loyalty.
#
# Learning Cycle 3:
# Situation: Customer needs urgent help
# Current Strategy: To address the recent failures of providing overly factual responses without sufficient empathy, the following improved approach can be implemented:
#
# ### 1. **Empathetic Communication:**
#    - **Acknowledge Emotions:** Begin interactions by validating the customer's feelings. Use empathetic phrases such as "I understand how this situation can be upsetting" or "It’s completely normal to feel this way."
#    - **Personalize Responses:** Incorporate the customer's name and specific details about their situation to create a more personal connection. For example, "Thank you for reaching out, [Customer's Name]. I see that you’re facing an issue with [specific issue]."
#
# ### 2. **Active Listening:**
#    - **Encourage Dialogue:** Use open-ended questions to invite customers to share more about their experiences. For instance, "What specific challenges are you facing with this issue?"
#    - **Reflect Back:** Paraphrase the customer's concerns to demonstrate understanding and ensure clarity. For example, "So what I’m hearing is that you’re feeling frustrated because [summarize their concern]. Is that correct?"
#
# ### 3. **Balanced Information Delivery:**
#    - **Combine Facts with Support:** When delivering factual information, accompany it with empathetic language. For example, "While our policy states X, I understand that this may not be the outcome you were hoping for, and I’m here to help you find a solution."
#    - **Offer Solutions:** Instead of merely stating facts, provide actionable steps the customer can take. For example, "You can try [solution], and I can guide you through the process."
#
# ### 4. **Follow-Up:**
#    - **Check-In:** After resolving the issue, follow up with the customer to ensure their needs are met. A simple message like, "I just wanted to check in and see if everything is working well for you now," can go a long way.
#    - **Feedback Loop:** Encourage customers to share their feedback on the interaction, which can help refine your empathetic approach. Ask questions like, "How did you feel about our conversation today?"
#
# ### 5. **Training and Development:**
#    - **Empathy Training:** Provide training sessions focused on developing emotional intelligence and empathetic communication skills among team members.
#    - **Role-Playing Scenarios:** Implement role-playing exercises that simulate customer interactions, allowing team members to practice responding with empathy while delivering factual information.
#
# ### 6. **Utilize Technology:**
#    - **AI and Chatbots:** If using automated systems, ensure they are designed to recognize emotional cues and respond with empathy. For example, a chatbot could say, "I’m sorry to hear that you’re having trouble. Let’s see how I can assist you."
#
# ### 7. **Create a Supportive Culture:**
#    - **Encourage Empathy Among Staff:** Foster a workplace culture that prioritizes empathy and customer care, which can enhance customer interactions.
#    - **Recognize and Reward Empathy:** Acknowledge and reward team members who demonstrate exceptional empathetic customer service, reinforcing the importance of this approach.
#
# ### 8. **Continuous Improvement:**
#    - **Monitor Interactions:** Regularly review customer interactions to identify areas for improvement in empathetic communication.
#    - **Adapt Strategies:** Be open to adapting strategies based on customer feedback and changing needs, ensuring that empathy remains a core component of your service.
#
# By implementing these strategies, you can create a more holistic approach that not only delivers factual information but also fosters emotional connections with customers, leading to enhanced satisfaction and loyalty.
# Strategy Change: Strategy updated due to low success rate (0.0%)
# New Strategy: To address the recent failures of providing overly factual responses and lacking urgency, while still maintaining an empathetic approach, the following improved strategy can be implemented:
#
# ### 1. **Urgency Recognition:**
#    - **Assess Customer Needs Quickly:** Train team members to quickly gauge the urgency of customer issues. Use phrases like, "I can see this is important to you, and I want to help you as quickly as possible."
#    - **Prioritize Responses:** Develop a system to categorize inquiries based on urgency, ensuring that high-priority issues are addressed first.
#
# ### 2. **Empathetic and Timely Communication:**
#    - **Immediate Acknowledgment:** Upon receiving a customer inquiry, respond promptly with an acknowledgment that shows understanding of their urgency. For example, "Thank you for reaching out, [Customer's Name]. I understand that this is urgent, and I’m here to help you right away."
#    - **Set Expectations:** Clearly communicate timelines for resolution. For instance, "I will do my best to resolve this within the next hour. Thank you for your patience."
#
# ### 3. **Streamlined Information Delivery:**
#    - **Concise and Relevant Information:** Provide essential information quickly, avoiding unnecessary details. Use bullet points or numbered lists for clarity when appropriate.
#    - **Empathy in Facts:** When delivering factual information, frame it with empathetic language. For example, "I understand that our policy may not align with your expectations, but here’s what we can do to assist you."
#
# ### 4. **Proactive Problem Solving:**
#    - **Anticipate Needs:** Train team members to anticipate potential follow-up questions or concerns and address them proactively. For example, "I know you might be worried about [related issue], and here’s how we can address that."
#    - **Offer Multiple Solutions:** Present customers with options to resolve their issues, allowing them to choose the path that best suits their needs. For example, "You can either [solution A] or [solution B]. Which would you prefer?"
#
# ### 5. **Enhanced Follow-Up Procedures:**
#    - **Timely Check-Ins:** Implement a follow-up protocol that ensures customers are contacted shortly after their issue is resolved to confirm satisfaction. For example, "I wanted to follow up to ensure everything is working well for you now."
#    - **Feedback Mechanism:** Encourage customers to provide feedback on the speed and empathy of the service they received. Use this feedback to make continuous improvements.
#
# ### 6. **Empathy and Urgency Training:**
#    - **Focused Training Sessions:** Conduct training that emphasizes the importance of balancing empathy with urgency. Use real-life scenarios to illustrate effective responses.
#    - **Role-Playing with Time Constraints:** Implement role-playing exercises that simulate urgent customer interactions, allowing team members to practice responding quickly and empathetically.
#
# ### 7. **Leverage Technology for Efficiency:**
#    - **AI-Powered Support:** Utilize AI tools that can prioritize inquiries based on urgency and provide initial empathetic responses. For example, a chatbot could say, "I understand this is urgent. Let’s get started on resolving this issue right away."
#    - **Automated Alerts:** Set up automated alerts for team members when urgent issues are flagged, ensuring they are addressed promptly.
#
# ### 8. **Foster a Culture of Empathy and Urgency:**
#    - **Team Recognition:** Recognize and reward team members who excel in balancing empathy with urgency, reinforcing the importance of this dual approach.
#    - **Encourage Open Communication:** Create an environment where team members feel comfortable discussing challenges in meeting customer needs, fostering a culture of continuous improvement.
#
# ### 9. **Continuous Monitoring and Adaptation:**
#    - **Review Performance Metrics:** Regularly analyze customer interactions to assess response times and the effectiveness of empathetic communication.
#    - **Adapt Strategies Based on Feedback:** Be flexible in adapting strategies based on customer feedback and evolving needs, ensuring that both empathy and urgency remain central to your service approach.
#
# By implementing these strategies, you can create a more responsive and empathetic customer service experience that addresses both the emotional and urgent needs of customers, ultimately leading to higher satisfaction and loyalty.
#
# Learning Cycle 4:
# Situation: Customer happy but has question
# Current Strategy: To address the recent failures of providing overly factual responses and lacking urgency, while still maintaining an empathetic approach, the following improved strategy can be implemented:
#
# ### 1. **Urgency Recognition:**
#    - **Assess Customer Needs Quickly:** Train team members to quickly gauge the urgency of customer issues. Use phrases like, "I can see this is important to you, and I want to help you as quickly as possible."
#    - **Prioritize Responses:** Develop a system to categorize inquiries based on urgency, ensuring that high-priority issues are addressed first.
#
# ### 2. **Empathetic and Timely Communication:**
#    - **Immediate Acknowledgment:** Upon receiving a customer inquiry, respond promptly with an acknowledgment that shows understanding of their urgency. For example, "Thank you for reaching out, [Customer's Name]. I understand that this is urgent, and I’m here to help you right away."
#    - **Set Expectations:** Clearly communicate timelines for resolution. For instance, "I will do my best to resolve this within the next hour. Thank you for your patience."
#
# ### 3. **Streamlined Information Delivery:**
#    - **Concise and Relevant Information:** Provide essential information quickly, avoiding unnecessary details. Use bullet points or numbered lists for clarity when appropriate.
#    - **Empathy in Facts:** When delivering factual information, frame it with empathetic language. For example, "I understand that our policy may not align with your expectations, but here’s what we can do to assist you."
#
# ### 4. **Proactive Problem Solving:**
#    - **Anticipate Needs:** Train team members to anticipate potential follow-up questions or concerns and address them proactively. For example, "I know you might be worried about [related issue], and here’s how we can address that."
#    - **Offer Multiple Solutions:** Present customers with options to resolve their issues, allowing them to choose the path that best suits their needs. For example, "You can either [solution A] or [solution B]. Which would you prefer?"
#
# ### 5. **Enhanced Follow-Up Procedures:**
#    - **Timely Check-Ins:** Implement a follow-up protocol that ensures customers are contacted shortly after their issue is resolved to confirm satisfaction. For example, "I wanted to follow up to ensure everything is working well for you now."
#    - **Feedback Mechanism:** Encourage customers to provide feedback on the speed and empathy of the service they received. Use this feedback to make continuous improvements.
#
# ### 6. **Empathy and Urgency Training:**
#    - **Focused Training Sessions:** Conduct training that emphasizes the importance of balancing empathy with urgency. Use real-life scenarios to illustrate effective responses.
#    - **Role-Playing with Time Constraints:** Implement role-playing exercises that simulate urgent customer interactions, allowing team members to practice responding quickly and empathetically.
#
# ### 7. **Leverage Technology for Efficiency:**
#    - **AI-Powered Support:** Utilize AI tools that can prioritize inquiries based on urgency and provide initial empathetic responses. For example, a chatbot could say, "I understand this is urgent. Let’s get started on resolving this issue right away."
#    - **Automated Alerts:** Set up automated alerts for team members when urgent issues are flagged, ensuring they are addressed promptly.
#
# ### 8. **Foster a Culture of Empathy and Urgency:**
#    - **Team Recognition:** Recognize and reward team members who excel in balancing empathy with urgency, reinforcing the importance of this dual approach.
#    - **Encourage Open Communication:** Create an environment where team members feel comfortable discussing challenges in meeting customer needs, fostering a culture of continuous improvement.
#
# ### 9. **Continuous Monitoring and Adaptation:**
#    - **Review Performance Metrics:** Regularly analyze customer interactions to assess response times and the effectiveness of empathetic communication.
#    - **Adapt Strategies Based on Feedback:** Be flexible in adapting strategies based on customer feedback and evolving needs, ensuring that both empathy and urgency remain central to your service approach.
#
# By implementing these strategies, you can create a more responsive and empathetic customer service experience that addresses both the emotional and urgent needs of customers, ultimately leading to higher satisfaction and loyalty.
# Strategy Change: Strategy updated due to low success rate (25.0%)
# New Strategy: To improve upon the identified failures of being too slow and not recognizing urgency, a more refined approach can be adopted. Here’s a suggested strategy that emphasizes speed, urgency recognition, and empathetic communication:
#
# ### 1. **Urgency Assessment Framework:**
#    - **Initial Triage System:** Implement a triage system that allows team members to quickly categorize inquiries based on urgency. This could involve a simple tagging system (e.g., urgent, high, medium, low) that helps prioritize responses.
#    - **Urgency Indicators:** Train team members to recognize specific keywords or phrases in customer inquiries that indicate urgency (e.g., "immediate," "emergency," "critical").
#
# ### 2. **Rapid Response Protocol:**
#    - **First Response Time Goals:** Set clear goals for first response times based on urgency levels. For example, urgent inquiries should receive a response within 15 minutes, while high-priority issues should be addressed within 30 minutes.
#    - **Dedicated Urgent Response Team:** Consider creating a specialized team or shift dedicated to handling urgent inquiries, ensuring that these issues are prioritized and resolved quickly.
#
# ### 3. **Empathetic Acknowledgment:**
#    - **Personalized Responses:** Use the customer’s name and reference their specific issue in the acknowledgment message to create a personal connection. For example, "Hi [Customer's Name], I understand that your issue with [specific problem] is urgent, and I’m here to assist you right away."
#    - **Express Understanding:** Use empathetic language that validates the customer’s feelings. For instance, "I can imagine how frustrating this must be for you, and I want to resolve it as quickly as possible."
#
# ### 4. **Streamlined Communication:**
#    - **Use of Templates:** Develop templates for common urgent inquiries that can be quickly customized. This allows for faster responses while maintaining a personal touch.
#    - **Clear and Direct Language:** Avoid jargon and provide straightforward answers. For example, "Here’s what we can do to resolve this issue immediately."
#
# ### 5. **Proactive Engagement:**
#    - **Anticipate Follow-Up Needs:** After addressing the immediate concern, proactively offer additional assistance. For example, "Now that we’ve resolved your issue, is there anything else I can help you with today?"
#    - **Provide Contextual Solutions:** When presenting solutions, explain why they are the best options for the customer’s urgent situation.
#
# ### 6. **Feedback Loop for Continuous Improvement:**
#    - **Post-Interaction Surveys:** Implement quick surveys after each interaction to gauge customer satisfaction with response time and empathy. Use this data to identify areas for improvement.
#    - **Regular Team Debriefs:** Hold regular meetings to discuss urgent cases, share best practices, and learn from any challenges faced in recognizing and addressing urgency.
#
# ### 7. **Technology Integration:**
#    - **AI-Powered Prioritization:** Utilize AI tools that can analyze incoming inquiries and flag those that indicate urgency, allowing human agents to focus on high-priority cases.
#    - **Real-Time Dashboards:** Create dashboards that display real-time metrics on response times and customer satisfaction, helping teams stay accountable and focused on urgent issues.
#
# ### 8. **Empathy and Urgency Training:**
#    - **Scenario-Based Training:** Conduct training sessions that simulate urgent customer interactions, allowing team members to practice quick, empathetic responses in a controlled environment.
#    - **Regular Refresher Courses:** Offer ongoing training to reinforce the importance of urgency and empathy in customer service.
#
# ### 9. **Recognition and Incentives:**
#    - **Reward Quick Resolvers:** Implement a recognition program that rewards team members who consistently demonstrate the ability to respond quickly and empathetically to urgent inquiries.
#    - **Team Celebrations:** Celebrate team successes in improving response times and customer satisfaction, fostering a culture of urgency and empathy.
#
# ### 10. **Monitoring and Adaptation:**
#    - **Analyze Response Data:** Regularly review response time data and customer feedback to identify trends and areas for improvement.
#    - **Adapt Strategies as Needed:** Be flexible in adjusting strategies based on performance metrics and customer needs, ensuring that the focus on urgency and empathy remains strong.
#
# By implementing this improved approach, the organization can better recognize urgency, respond more quickly, and maintain an empathetic connection with customers, ultimately enhancing overall customer satisfaction and loyalty.
#
# FINAL STRATEGY: To improve upon the identified failures of being too slow and not recognizing urgency, a more refined approach can be adopted. Here’s a suggested strategy that emphasizes speed, urgency recognition, and empathetic communication:
#
# ### 1. **Urgency Assessment Framework:**
#    - **Initial Triage System:** Implement a triage system that allows team members to quickly categorize inquiries based on urgency. This could involve a simple tagging system (e.g., urgent, high, medium, low) that helps prioritize responses.
#    - **Urgency Indicators:** Train team members to recognize specific keywords or phrases in customer inquiries that indicate urgency (e.g., "immediate," "emergency," "critical").
#
# ### 2. **Rapid Response Protocol:**
#    - **First Response Time Goals:** Set clear goals for first response times based on urgency levels. For example, urgent inquiries should receive a response within 15 minutes, while high-priority issues should be addressed within 30 minutes.
#    - **Dedicated Urgent Response Team:** Consider creating a specialized team or shift dedicated to handling urgent inquiries, ensuring that these issues are prioritized and resolved quickly.
#
# ### 3. **Empathetic Acknowledgment:**
#    - **Personalized Responses:** Use the customer’s name and reference their specific issue in the acknowledgment message to create a personal connection. For example, "Hi [Customer's Name], I understand that your issue with [specific problem] is urgent, and I’m here to assist you right away."
#    - **Express Understanding:** Use empathetic language that validates the customer’s feelings. For instance, "I can imagine how frustrating this must be for you, and I want to resolve it as quickly as possible."
#
# ### 4. **Streamlined Communication:**
#    - **Use of Templates:** Develop templates for common urgent inquiries that can be quickly customized. This allows for faster responses while maintaining a personal touch.
#    - **Clear and Direct Language:** Avoid jargon and provide straightforward answers. For example, "Here’s what we can do to resolve this issue immediately."
#
# ### 5. **Proactive Engagement:**
#    - **Anticipate Follow-Up Needs:** After addressing the immediate concern, proactively offer additional assistance. For example, "Now that we’ve resolved your issue, is there anything else I can help you with today?"
#    - **Provide Contextual Solutions:** When presenting solutions, explain why they are the best options for the customer’s urgent situation.
#
# ### 6. **Feedback Loop for Continuous Improvement:**
#    - **Post-Interaction Surveys:** Implement quick surveys after each interaction to gauge customer satisfaction with response time and empathy. Use this data to identify areas for improvement.
#    - **Regular Team Debriefs:** Hold regular meetings to discuss urgent cases, share best practices, and learn from any challenges faced in recognizing and addressing urgency.
#
# ### 7. **Technology Integration:**
#    - **AI-Powered Prioritization:** Utilize AI tools that can analyze incoming inquiries and flag those that indicate urgency, allowing human agents to focus on high-priority cases.
#    - **Real-Time Dashboards:** Create dashboards that display real-time metrics on response times and customer satisfaction, helping teams stay accountable and focused on urgent issues.
#
# ### 8. **Empathy and Urgency Training:**
#    - **Scenario-Based Training:** Conduct training sessions that simulate urgent customer interactions, allowing team members to practice quick, empathetic responses in a controlled environment.
#    - **Regular Refresher Courses:** Offer ongoing training to reinforce the importance of urgency and empathy in customer service.
#
# ### 9. **Recognition and Incentives:**
#    - **Reward Quick Resolvers:** Implement a recognition program that rewards team members who consistently demonstrate the ability to respond quickly and empathetically to urgent inquiries.
#    - **Team Celebrations:** Celebrate team successes in improving response times and customer satisfaction, fostering a culture of urgency and empathy.
#
# ### 10. **Monitoring and Adaptation:**
#    - **Analyze Response Data:** Regularly review response time data and customer feedback to identify trends and areas for improvement.
#    - **Adapt Strategies as Needed:** Be flexible in adjusting strategies based on performance metrics and customer needs, ensuring that the focus on urgency and empathy remains strong.
#
# By implementing this improved approach, the organization can better recognize urgency, respond more quickly, and maintain an empathetic connection with customers, ultimately enhancing overall customer satisfaction and loyalty.
# Final Success Rate: 25.0%

# %% [markdown]
# Key Learning Points from this Code:
#
# Reinforcement Loop: ACT → OBSERVE → ADAPT cycle
#
# Strategy Evolution: Agents improve based on feedback
#
# Adaptive Planning: Plans change based on situation type
#
# Continuous Learning: Each interaction informs future behavior

# %% [markdown]
# ## When to Use This Approach:
#
# This Python-only RL loop is ideal when:
#
# You want learning over time but don’t need complex RL algorithms.
#
# You're building conversational or reasoning agents that rely on strategy, not action probabilities.
#
# You want full control and transparency in code, without agent frameworks.
#
# Production Considerations: To make this RL-style loop production-ready, apply the following upgrades:
#
# 1. Persistent Memory Storage
#
# 2. Reward Automation
#
# 3. Strategy Versioning
#
# 4. Guardrails + Safety Policies
#
# 5. Rapid Adaptation with Weighted Feedback
#
# 6. Caching for Cost Optimization
