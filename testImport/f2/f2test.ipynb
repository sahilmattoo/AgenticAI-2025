# %%
# Ensure the parent directory is in the Python path
import sys
sys.path.append("../f1")  # Add the f1 directory to the path

from f1 import f1test  # Import the f1test module
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 5
#       2 import sys
#       3 sys.path.append("../f1")  # Add the f1 directory to the path
# ----> 5 from f1 import f1test
#
# ModuleNotFoundError: No module named 'f1'

# %%
# Execute the imported f1test function and print its return value if any.
result = f1test()
if result is not None:
    print("f1test returned:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Execute the imported f1test function and print its return value if any.
# ----> 2 result = f1test()
#       3 if result is not None:
#       4     print("f1test returned:", result)
#
# NameError: name 'f1test' is not defined

# %%
import importlib
import f1test as f1mod

# Call the f1test function if it's already imported; otherwise import and call it.
try:
    result = f1test()
except NameError:
    importlib.reload(f1mod)
    result = f1mod.f1test()

if result is not None:
    print("f1test returned:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       5 try:
# ----> 6     result = f1test()
#       7 except NameError:
#
# NameError: name 'f1test' is not defined
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 9
#       7 except NameError:
#       8     importlib.reload(f1mod)
# ----> 9     result = f1mod.f1test()
#      11 if result is not None:
#      12     print("f1test returned:", result)
#
# AttributeError: module 'f1test' has no attribute 'f1test'

# %%
# Example usage of f1test
f1test()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Example usage of f1test
# ----> 2 f1test()
#
# NameError: name 'f1test' is not defined
